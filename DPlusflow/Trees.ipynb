# %%
import pandas as pd
import matplotlib.pyplot as plt
import uproot

# %%
dfsData = []
dfsDataLite = []
with uproot.open('/home/mdicosta/LocalTestsO2/DPlusflow/AO2D.root') as f:
    print(f.keys())
    for iKey, key in enumerate(f.keys()):
        if 'O2hfcandptcent' in key:
            print(key)
            dfData = f[key].arrays(library='pd')
            dfsData.append(dfData)

full_df = pd.concat([df for df in dfsData], ignore_index=True)
print(f"len(full_df): {len(full_df)}")
# Out:
# ['DF_2336518079463007;1', 'DF_2336518079463007/O2hfcandptcent;1', 'DF_2336518079463039;1', 'DF_2336518079463039/O2hfcandptcent;1', 'DF_2336518079646559;1', 'DF_2336518079646559/O2hfcandptcent;1', 'parentFiles;1']
# DF_2336518079463007/O2hfcandptcent;1
# DF_2336518079463039/O2hfcandptcent;1
# DF_2336518079646559/O2hfcandptcent;1
# len(full_df): 60

# %%
print(full_df.columns)
# Out:
# Index(['fM', 'fPt', 'fMlScore0', 'fMlScore1'], dtype='object')

# %%
n_columns = len(full_df.columns)
n_rows = (n_columns // 4) + (1 if n_columns % 4 else 0)

fig, axes = plt.subplots(n_rows, 4, figsize=(15, 5 * n_rows))
axes = axes.flatten()
for i, column in enumerate(full_df.columns):
    print(f"Plotting {column}")
    axes[i].hist(full_df[column], bins=50, color='blue') #, density=True)
    axes[i].set_title(f'{column}')
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')
    # axes[i].set_yscale('log')
    axes[i].legend()  # Add legend to the current axis

# Remove unused axes if any
for i in range(n_columns, len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()
# Out:
# Plotting fM
# Plotting fPt
# Plotting fMlScore0
# Plotting fMlScore1
# /tmp/ipykernel_4069541/3002618493.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[i].legend()  # Add legend to the current axis
