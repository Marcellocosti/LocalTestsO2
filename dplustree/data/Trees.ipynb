# %%
import pandas as pd
import matplotlib.pyplot as plt
import uproot

# %%
dfsData = []
dfsDataLite = []
with uproot.open('/home/mdicosta/LocalTestsO2/dplustree/data/AO2D.root') as f:
    print(f.keys())
    for iKey, key in enumerate(f.keys()):
        if 'O2hfcanddplite' in key:
            print(key)
            dfData = f[key].arrays(library='pd')
            dfsData.append(dfData)

full_df = pd.concat([df for df in dfsData], ignore_index=True)
print(f"len(full_df): {len(full_df)}")
# Out:
# ['DF_2336986349216218;1', 'DF_2336986349216218/O2hfcanddplite;1', 'DF_2336986349216218/O2hfcanddpml;1', 'DF_2336986349216250;1', 'DF_2336986349216250/O2hfcanddplite;1', 'DF_2336986349216250/O2hfcanddpml;1', 'DF_2336986349216282;1', 'DF_2336986349216282/O2hfcanddplite;1', 'DF_2336986349216282/O2hfcanddpml;1', 'DF_2336986349216314;1', 'DF_2336986349216314/O2hfcanddplite;1', 'DF_2336986349216314/O2hfcanddpml;1', 'DF_2336986349216346;1', 'DF_2336986349216346/O2hfcanddplite;1', 'DF_2336986349216346/O2hfcanddpml;1', 'DF_2336986349336698;1', 'DF_2336986349336698/O2hfcanddplite;1', 'DF_2336986349336698/O2hfcanddpml;1', 'DF_2336986349336730;1', 'DF_2336986349336730/O2hfcanddplite;1', 'DF_2336986349336730/O2hfcanddpml;1', 'DF_2336986349336762;1', 'DF_2336986349336762/O2hfcanddplite;1', 'DF_2336986349336762/O2hfcanddpml;1', 'DF_2336986349336794;1', 'DF_2336986349336794/O2hfcanddplite;1', 'DF_2336986349336794/O2hfcanddpml;1', 'DF_2336986349336826;1', 'DF_2336986349336826/O2hfcanddplite;1', 'DF_2336986349336826/O2hfcanddpml;1', 'DF_2336986349393818;1', 'DF_2336986349393818/O2hfcanddplite;1', 'DF_2336986349393818/O2hfcanddpml;1', 'DF_2336986349393850;1', 'DF_2336986349393850/O2hfcanddplite;1', 'DF_2336986349393850/O2hfcanddpml;1', 'DF_2336986349393882;1', 'DF_2336986349393882/O2hfcanddplite;1', 'DF_2336986349393882/O2hfcanddpml;1', 'DF_2336986349393914;1', 'DF_2336986349393914/O2hfcanddplite;1', 'DF_2336986349393914/O2hfcanddpml;1', 'DF_2336986349393946;1', 'DF_2336986349393946/O2hfcanddplite;1', 'DF_2336986349393946/O2hfcanddpml;1', 'DF_2336986349628378;1', 'DF_2336986349628378/O2hfcanddplite;1', 'DF_2336986349628378/O2hfcanddpml;1', 'DF_2336986349628410;1', 'DF_2336986349628410/O2hfcanddplite;1', 'DF_2336986349628410/O2hfcanddpml;1', 'DF_2336986349628442;1', 'DF_2336986349628442/O2hfcanddplite;1', 'DF_2336986349628442/O2hfcanddpml;1', 'DF_2336986349628474;1', 'DF_2336986349628474/O2hfcanddplite;1', 'DF_2336986349628474/O2hfcanddpml;1', 'DF_2336986349628506;1', 'DF_2336986349628506/O2hfcanddplite;1', 'DF_2336986349628506/O2hfcanddpml;1', 'DF_2336986350465338;1', 'DF_2336986350465338/O2hfcanddplite;1', 'DF_2336986350465338/O2hfcanddpml;1', 'DF_2336986350465370;1', 'DF_2336986350465370/O2hfcanddplite;1', 'DF_2336986350465370/O2hfcanddpml;1', 'DF_2336986350465402;1', 'DF_2336986350465402/O2hfcanddplite;1', 'DF_2
# DF_2336986351454394/O2hfcanddplite;1
# DF_2336986351454426/O2hfcanddplite;1
# DF_2336986351993338/O2hfcanddplite;1
# DF_2336986351993370/O2hfcanddplite;1
# DF_2336986351993402/O2hfcanddplite;1
# DF_2336986351993434/O2hfcanddplite;1
# DF_2336986351993466/O2hfcanddplite;1
# DF_2336986352411738/O2hfcanddplite;1
# DF_2336986352411770/O2hfcanddplite;1
# DF_2336986352411802/O2hfcanddplite;1
# DF_2336986352411834/O2hfcanddplite;1
# DF_2336986352411866/O2hfcanddplite;1
# DF_2336986352785818/O2hfcanddplite;1
# DF_2336986352785850/O2hfcanddplite;1
# DF_2336986352785882/O2hfcanddplite;1
# DF_2336986352785914/O2hfcanddplite;1
# DF_2336986352785946/O2hfcanddplite;1
# DF_2336986353622778/O2hfcanddplite;1
# DF_2336986353622810/O2hfcanddplite;1
# DF_2336986353622874/O2hfcanddplite;1
# len(full_df): 2843

# %%
print(full_df.columns)
# Out:
# Index(['fChi2PCA', 'fDecayLength', 'fDecayLengthXY', 'fDecayLengthNormalised',
#        'fDecayLengthXYNormalised', 'fPtProng0', 'fPtProng1', 'fPtProng2',
#        'fImpactParameter0', 'fImpactParameter1', 'fImpactParameter2',
#        'fImpactParameterZ0', 'fImpactParameterZ1', 'fImpactParameterZ2',
#        'fNSigTpcPi0', 'fNSigTpcKa0', 'fNSigTofPi0', 'fNSigTofKa0',
#        'fNSigTpcTofPi0', 'fNSigTpcTofKa0', 'fNSigTpcPi1', 'fNSigTpcKa1',
#        'fNSigTofPi1', 'fNSigTofKa1', 'fNSigTpcTofPi1', 'fNSigTpcTofKa1',
#        'fNSigTpcPi2', 'fNSigTpcKa2', 'fNSigTofPi2', 'fNSigTofKa2',
#        'fNSigTpcTofPi2', 'fNSigTpcTofKa2', 'fCandidateSelFlag', 'fM', 'fPt',
#        'fCpa', 'fCpaXY', 'fMaxNormalisedDeltaIP', 'fEta', 'fPhi', 'fY',
#        'fCentrality', 'fFlagMcMatchRec', 'fOriginMcRec',
#        'fFlagMcDecayChanRec'],
#       dtype='object')

# %%
unique_values = full_df['fCentrality'].unique()
print("Unique values in fCentrality:", unique_values)
# Out:
# Unique values in fCentrality: [-1.]

# %%
unique_values = full_df['fFlagMcMatchRec'].unique()
print("Unique values in fFlagMcMatchRec:", unique_values)
# Out:
# Unique values in fFlagMcMatchRec: [0]

# %%
unique_values = full_df['fFlagMcDecayChanRec'].unique()
print("Unique values in fFlagMcDecayChanRec:", unique_values)
# Out:
# Unique values in fFlagMcDecayChanRec: [0]

# %%
n_columns = len(full_df.columns)
n_rows = (n_columns // 4) + (1 if n_columns % 4 else 0)

fig, axes = plt.subplots(n_rows, 4, figsize=(15, 5 * n_rows))
axes = axes.flatten()
for i, column in enumerate(full_df.columns):
    axes[i].hist(full_df[column], bins=50, color='blue', density=True)
    axes[i].set_title(f'{column}')
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')
    # axes[i].set_yscale('log')
    axes[i].legend()  # Add legend to the current axis

# Remove unused axes if any
for i in range(n_columns, len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_822547/2406445017.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[i].legend()  # Add legend to the current axis

# %%
full_df['fCentrality'].hist(bins=50, color='blue', alpha=0.5, label='Matched')
# Out:
# <Axes: >
