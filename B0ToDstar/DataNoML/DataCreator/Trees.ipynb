# %%
import uproot
import pandas as pd
import matplotlib.pyplot as plt

tables = [
    "O2hfredcollision",
    "O2hfredcollcent",
    # "O2hfredqvector",     # NOT USED
    "O2hfredcollextra",
    "O2hforigcolcount",
    "O2hfredtrackbase",
    "O2hfredtrackcov",
    "O2hfredtrackpid",
    "O2hfredtrackmom",
    "O2hfred2prong",
    "O2hfred2prongcov",
    "O2hfred3prongml_001",
    "O2hfredmomddaugs",
    "O2hfredsoftpibase",
    "O2hfredsoftpicov",
    "O2hfredsoftpipid",
    "O2hfredpiddau0_001",
    "O2hfredpiddau1_001",
    "O2hfcandb0config",
    # "O2hfmcgenredb0",    # NOT USED
    # "O2hfmcrecreddstpi"  # NOT USED
]

with uproot.open("Tree.root") as f:
    keys = f.keys()
    print("ROOT Keys:", keys)
    
    for table in tables:
        # Filter keys that match the table name
        matched_keys = [key for key in keys if table in key]
        
        if not matched_keys:
            print(f"No keys found for table: {table}")
            continue
        
        dfs = []
        for key in matched_keys:
            print(f"Reading {key}")
            df = f[key].arrays(library="pd")
            dfs.append(df)
        
        full_df = pd.concat(dfs, ignore_index=True)
        print(f"\nTable: {table}")
        print(f"Number of entries: {len(full_df)}")
        print(f"Columns: {full_df.columns.tolist()}")
        
        # Plotting
        n_columns = len(full_df.columns)
        n_rows = (n_columns // 4) + (1 if n_columns % 4 else 0)
        
        fig, axes = plt.subplots(n_rows, 4, figsize=(15, 5 * n_rows))
        axes = axes.flatten()

        for i, column in enumerate(full_df.columns):
            print(f"Plotting {column}")
            try:
                axes[i].hist(full_df[column].dropna(), bins=50, color='blue')
                axes[i].set_title(f'{column}')
                axes[i].set_xlabel('Value')
                axes[i].set_ylabel('Frequency')
            except Exception as e:
                print(f"Could not plot column {column}: {e}")
                axes[i].set_visible(False)
        
        # Remove unused axes if any
        for i in range(n_columns, len(axes)):
            fig.delaxes(axes[i])
        
        fig.suptitle(f"Histograms for table: {table}", fontsize=16)
        plt.tight_layout(rect=[0, 0, 1, 0.96])
        plt.show()
# Out:
# ROOT Keys: ['DF_2387899194678550;1', 'DF_2387899194678550/O2hfcandb0config;1', 'DF_2387899194678550/O2hfmcgenredb0;1', 'DF_2387899194678550/O2hfmcrecreddstpi;1', 'DF_2387899194678550/O2hforigcolcount;1', 'DF_2387899194678550/O2hfred2prong;1', 'DF_2387899194678550/O2hfred2prongscov;1', 'DF_2387899194678550/O2hfred3prongml_001;1', 'DF_2387899194678550/O2hfredcollcent;1', 'DF_2387899194678550/O2hfredcollextra;1', 'DF_2387899194678550/O2hfredcollision;1', 'DF_2387899194678550/O2hfredmomddaugs;1', 'DF_2387899194678550/O2hfredpiddau0_001;1', 'DF_2387899194678550/O2hfredpiddau1_001;1', 'DF_2387899194678550/O2hfredqvector;1', 'DF_2387899194678550/O2hfredsoftpibase;1', 'DF_2387899194678550/O2hfredsoftpicov;1', 'DF_2387899194678550/O2hfredsoftpipid;1', 'DF_2387899194678550/O2hfredtrackbase;1', 'DF_2387899194678550/O2hfredtrackcov;1', 'DF_2387899194678550/O2hfredtrackmom;1', 'DF_2387899194678550/O2hfredtrackpid;1', 'parentFiles;1']
# Reading DF_2387899194678550/O2hfredcollision;1
#
# Table: O2hfredcollision
# Number of entries: 56
# Columns: ['fPosX', 'fPosY', 'fPosZ', 'fNumContrib', 'fHfCollisionRejectionMap', 'fBz']
# Plotting fPosX
# Plotting fPosY
# Plotting fPosZ
# Plotting fNumContrib
# Plotting fHfCollisionRejectionMap
# Plotting fBz
# Reading DF_2387899194678550/O2hfredcollcent;1
#
# Table: O2hfredcollcent
# Number of entries: 56
# Columns: ['fCentFT0C', 'fCentFT0M', 'fNumTracksInTimeRange', 'fSumAmpFT0CInTimeRange']
# Plotting fCentFT0C
# Plotting fCentFT0M
# Plotting fNumTracksInTimeRange
# Plotting fSumAmpFT0CInTimeRange
# Reading DF_2387899194678550/O2hfredcollextra;1
#
# Table: O2hfredcollextra
# Number of entries: 56
# Columns: ['fCovXX', 'fCovXY', 'fCovYY', 'fCovXZ', 'fCovYZ', 'fCovZZ']
# Plotting fCovXX
# Plotting fCovXY
# Plotting fCovYY
# Plotting fCovXZ
# Plotting fCovYZ
# Plotting fCovZZ
# Reading DF_2387899194678550/O2hforigcolcount;1
#
# Table: O2hforigcolcount
# Number of entries: 145
# Columns: ['fOriginalCollisionCount', 'fZvtxSelectedCollisionCount', 'fTriggerSelectedCollisionCount', 'fZvtxAndTriggerSelectedCollisionCount', 'fZvtxAndTriggerAndSoftTriggerSelectedCollisionCount', 'fAllSelectionsCollisionCount']
# Plotting fOriginalCollisionCount
# Plotting fZvtxSelectedCollisionCount
# Plotting fTriggerSelectedCollisionCount
# Plotting fZvtxAndTriggerSelectedCollisionCount
# Plotting fZvtxAndTriggerAndSoftTriggerSelectedCollisionCount
# Plotting fAllSelectionsCollisionCount
# Reading DF_2387899194678550/O2hfredtrackbase;1
#
# Table: O2hfredtrackbase
# Number of entries: 74
# Columns: ['fTrackId', 'fIndexHfRedCollisions', 'fX', 'fAlpha', 'fY', 'fZ', 'fSnp', 'fTgl', 'fSigned1Pt', 'fItsNCls', 'fTpcNClsCrossedRows', 'fTpcChi2NCl']
# Plotting fTrackId
# Plotting fIndexHfRedCollisions
# Plotting fX
# Plotting fAlpha
# Plotting fY
# Plotting fZ
# Plotting fSnp
# Plotting fTgl
# Plotting fSigned1Pt
# Plotting fItsNCls
# Plotting fTpcNClsCrossedRows
# Plotting fTpcChi2NCl
# Reading DF_2387899194678550/O2hfredtrackcov;1
#
# Table: O2hfredtrackcov
# Number of entries: 74
# Columns: ['fCYY', 'fCZY', 'fCZZ', 'fCSnpY', 'fCSnpZ', 'fCSnpSnp', 'fCTglY', 'fCTglZ', 'fCTglSnp', 'fCTglTgl', 'fC1PtY', 'fC1PtZ', 'fC1PtSnp', 'fC1PtTgl', 'fC1Pt21Pt2']
# Plotting fCYY
# Plotting fCZY
# Plotting fCZZ
# Plotting fCSnpY
# Plotting fCSnpZ
# Plotting fCSnpSnp
# Plotting fCTglY
# Plotting fCTglZ
# Plotting fCTglSnp
# Plotting fCTglTgl
# Plotting fC1PtY
# Plotting fC1PtZ
# Plotting fC1PtSnp
# Plotting fC1PtTgl
# Plotting fC1Pt21Pt2
# Reading DF_2387899194678550/O2hfredtrackpid;1
#
# Table: O2hfredtrackpid
# Number of entries: 74
# Columns: ['fHasTPC', 'fHasTOF', 'fTPCNSigmaPi', 'fTOFNSigmaPi']
# Plotting fHasTPC
# Plotting fHasTOF
# Could not plot column fHasTOF: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.
# Plotting fTPCNSigmaPi
# Plotting fTOFNSigmaPi
# Reading DF_2387899194678550/O2hfredtrackmom;1
#
# Table: O2hfredtrackmom
# Number of entries: 74
# Columns: ['fPx', 'fPy', 'fPz', 'fSign']
# Plotting fPx
# Plotting fPy
# Plotting fPz
# Plotting fSign
# Reading DF_2387899194678550/O2hfred2prong;1
# Reading DF_2387899194678550/O2hfred2prongscov;1
#
# Table: O2hfred2prong
# Number of entries: 128
# Columns: ['fProng0Id', 'fProng1Id', 'fIndexHfRedCollisions', 'fX', 'fAlpha', 'fY', 'fZ', 'fSnp', 'fTgl', 'fSigned1Pt', 'fXSecondaryVertex', 'fYSecondaryVertex', 'fZSecondaryVertex', 'fInvMassHypo0', 'fInvMassHypo1', 'fPtProngMin', 'fAbsEtaProngMin', 'fItsNClsProngMin', 'fTpcNClsCrossedRowsProngMin', 'fTpcChi2NClProngMax', 'fCYY', 'fCZY', 'fCZZ', 'fCSnpY', 'fCSnpZ', 'fCSnpSnp', 'fCTglY', 'fCTglZ', 'fCTglSnp', 'fCTglTgl', 'fC1PtY', 'fC1PtZ', 'fC1PtSnp', 'fC1PtTgl', 'fC1Pt21Pt2']
# Plotting fProng0Id
# Plotting fProng1Id
# Plotting fIndexHfRedCollisions
# Plotting fX
# Plotting fAlpha
# Plotting fY
# Plotting fZ
# Plotting fSnp
# Plotting fTgl
# Plotting fSigned1Pt
# Plotting fXSecondaryVertex
# Plotting fYSecondaryVertex
# Plotting fZSecondaryVertex
# Plotting fInvMassHypo0
# Plotting fInvMassHypo1
# Plotting fPtProngMin
# Plotting fAbsEtaProngMin
# Plotting fItsNClsProngMin
# Plotting fTpcNClsCrossedRowsProngMin
# Plotting fTpcChi2NClProngMax
# Plotting fCYY
# Plotting fCZY
# Plotting fCZZ
# Plotting fCSnpY
# Plotting fCSnpZ
# Plotting fCSnpSnp
# Plotting fCTglY
# Plotting fCTglZ
# Plotting fCTglSnp
# Plotting fCTglTgl
# Plotting fC1PtY
# Plotting fC1PtZ
# Plotting fC1PtSnp
# Plotting fC1PtTgl
# Plotting fC1Pt21Pt2
# No keys found for table: O2hfred2prongcov
# Reading DF_2387899194678550/O2hfred3prongml_001;1
#
# Table: O2hfred3prongml_001
# Number of entries: 0
# Columns: ['fMlScoreBkgMassHypo0', 'fMlScorePromptMassHypo0', 'fMlScoreNonpromptMassHypo0', 'fMlScoreBkgMassHypo1', 'fMlScorePromptMassHypo1', 'fMlScoreNonpromptMassHypo1']
# Plotting fMlScoreBkgMassHypo0
# Plotting fMlScorePromptMassHypo0
# Plotting fMlScoreNonpromptMassHypo0
# Plotting fMlScoreBkgMassHypo1
# Plotting fMlScorePromptMassHypo1
# Plotting fMlScoreNonpromptMassHypo1
# Reading DF_2387899194678550/O2hfredmomddaugs;1
#
# Table: O2hfredmomddaugs
# Number of entries: 64
# Columns: ['fPxProng0', 'fPyProng0', 'fPzProng0', 'fPxProng1', 'fPyProng1', 'fPzProng1', 'fPxProng2', 'fPyProng2', 'fPzProng2']
# Plotting fPxProng0
# Plotting fPyProng0
# Plotting fPzProng0
# Plotting fPxProng1
# Plotting fPyProng1
# Plotting fPzProng1
# Plotting fPxProng2
# Plotting fPyProng2
# Plotting fPzProng2
# Reading DF_2387899194678550/O2hfredsoftpibase;1
#
# Table: O2hfredsoftpibase
# Number of entries: 64
# Columns: ['fTrackId', 'fIndexHfRedCollisions', 'fX', 'fAlpha', 'fY', 'fZ', 'fSnp', 'fTgl', 'fSigned1Pt', 'fItsNCls', 'fTpcNClsCrossedRows', 'fTpcChi2NCl']
# Plotting fTrackId
# Plotting fIndexHfRedCollisions
# Plotting fX
# Plotting fAlpha
# Plotting fY
# Plotting fZ
# Plotting fSnp
# Plotting fTgl
# Plotting fSigned1Pt
# Plotting fItsNCls
# Plotting fTpcNClsCrossedRows
# Plotting fTpcChi2NCl
# Reading DF_2387899194678550/O2hfredsoftpicov;1
#
# Table: O2hfredsoftpicov
# Number of entries: 64
# Columns: ['fCYY', 'fCZY', 'fCZZ', 'fCSnpY', 'fCSnpZ', 'fCSnpSnp', 'fCTglY', 'fCTglZ', 'fCTglSnp', 'fCTglTgl', 'fC1PtY', 'fC1PtZ', 'fC1PtSnp', 'fC1PtTgl', 'fC1Pt21Pt2']
# Plotting fCYY
# Plotting fCZY
# Plotting fCZZ
# Plotting fCSnpY
# Plotting fCSnpZ
# Plotting fCSnpSnp
# Plotting fCTglY
# Plotting fCTglZ
# Plotting fCTglSnp
# Plotting fCTglTgl
# Plotting fC1PtY
# Plotting fC1PtZ
# Plotting fC1PtSnp
# Plotting fC1PtTgl
# Plotting fC1Pt21Pt2
# Reading DF_2387899194678550/O2hfredsoftpipid;1
#
# Table: O2hfredsoftpipid
# Number of entries: 64
# Columns: ['fTPCNSigmaPiSoftPi', 'fTOFNSigmaPiSoftPi', 'fHasTOF', 'fHasTPC']
# Plotting fTPCNSigmaPiSoftPi
# Plotting fTOFNSigmaPiSoftPi
# Plotting fHasTOF
# Could not plot column fHasTOF: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.
# Plotting fHasTPC
# /home/mdicosta/virtenvpy/phys/lib/python3.12/site-packages/matplotlib/axes/_axes.py:7001: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
# Reading DF_2387899194678550/O2hfredpiddau0_001;1
#
# Table: O2hfredpiddau0_001
# Number of entries: 64
# Columns: ['fTPCNSigmaPiProng0', 'fTOFNSigmaPiProng0', 'fTPCNSigmaKaProng0', 'fTOFNSigmaKaProng0', 'fTPCNSigmaPrProng0', 'fTOFNSigmaPrProng0', 'fHasTOFProng0', 'fHasTPCProng0']
# Plotting fTPCNSigmaPiProng0
# Plotting fTOFNSigmaPiProng0
# Plotting fTPCNSigmaKaProng0
# Plotting fTOFNSigmaKaProng0
# Plotting fTPCNSigmaPrProng0
# Plotting fTOFNSigmaPrProng0
# Plotting fHasTOFProng0
# Could not plot column fHasTOFProng0: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.
# Plotting fHasTPCProng0
# Reading DF_2387899194678550/O2hfredpiddau1_001;1
#
# Table: O2hfredpiddau1_001
# Number of entries: 64
# Columns: ['fTPCNSigmaPiProng1', 'fTOFNSigmaPiProng1', 'fTPCNSigmaKaProng1', 'fTOFNSigmaKaProng1', 'fTPCNSigmaPrProng1', 'fTOFNSigmaPrProng1', 'fHasTOFProng1', 'fHasTPCProng1']
# Plotting fTPCNSigmaPiProng1
# Plotting fTOFNSigmaPiProng1
# Plotting fTPCNSigmaKaProng1
# Plotting fTOFNSigmaKaProng1
# Plotting fTPCNSigmaPrProng1
# Plotting fTOFNSigmaPrProng1
# Plotting fHasTOFProng1
# Could not plot column fHasTOFProng1: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.
# Plotting fHasTPCProng1
# Reading DF_2387899194678550/O2hfcandb0config;1
#
# Table: O2hfcandb0config
# Number of entries: 1
# Columns: ['fMySelectionFlagD', 'fMyInvMassWindowDPi']
# Plotting fMySelectionFlagD
# Plotting fMyInvMassWindowDPi
